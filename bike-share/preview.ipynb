# %%
# import data
import pandas as pd

df = pd.read_csv("bike_sharing_dc.csv")

# %%
# explore data
import pygwalker as pyg

pyg.walk(df, spec="preview.json", use_preview=True)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0" style="height: auto">\n    <head>\n        <!-- ipywidgets.HTML …
# <html>
# <style>
# .tabs{
#     position:relative;
#     height:600px;
# }
# .tab-pane{
#     display:inline-block;
# }
# .tabs input[type='radio']{
#     position:absolute;
#     clip:rect(0,0,0,0)
# }
# .tab-item{
#     display:block;
#     height:34px;
#     line-height:34px;
#     cursor:pointer;
#     padding:0 10px
# }
#
# .tabs input[type='radio']:checked+.tab-item{
#     background:#2563eb;
#     color:#fff
# }
#
# .tab-content{
#     display: none;
#     position:absolute;
#     padding:20px;
#     left:0;
#     top:36px;
#     bottom:0;
#     right:0;
# }
#
# .tabs input[type='radio']:checked+.tab-item+.tab-content{
#     display: block;
#     z-index:1
# }
# </style>
#
# <body>
#     <div id="pygwalker-preview-0" class="tabs">
#
#         <div class="tab-pane">
#             <input type="radio" name="tab" id="tab-0-Explore" checked />
#             <label class="tab-item" for="tab-0-Explore">Explore</label>
#             <div class="tab-content"><div id="0-Explore" style="width: 100%; max-height: 600px;">
#
#     <h1 style="margin-top: 1rem; color: #333; font-size: 1.1rem; margin-bottom: 0.5rem; padding-inline-start: 1rem;">Explore</h1>
#
#     <p style="color: #666; font-weight: 300; padding-inline-start: 1rem;"></p>
#     <!-- <p>Under certain Jupyter environments, after launching pygwalker, the preview may not automatically hide. You can manually click the button to hide it.</p> -->
#     <div class="main-box">
#
#         <div style="display: flex;">
#
#             <div style="width: 350px; height: 244px">
#                 <img style="max-width: none;" height="244" width="350" src="data:image/png;base64,..." />
#             </div>
#
#         </div>
#
#     </div>
# </div></div>
#         </div>
#
#         <div class="tab-pane">
#             <input type="radio" name="tab" id="tab-0-Count Per Month" checked />
#             <label class="tab-item" for="tab-0-Count Per Month">Count Per Month</label>
#             <div class="tab-content"><div id="0-Count Per Month" style="width: 100%; max-height: 600px;">
#
#     <h1 style="margin-top: 1rem; color: #333; font-size: 1.1rem; margin-bottom: 0.5rem; padding-inline-start: 1rem;">Count Per Month</h1>
#
#     <p style="color: #666; font-weight: 300; padding-inline-start: 1rem;"></p>
#     <!-- <p>Under certain Jupyter environments, after launching pygwalker, the preview may not automatically hide. You can manually click the button to hide it.</p> -->
#     <div class="main-box">
#
#         <div style="display: flex;">
#
#             <div style="width: 397px; height: 243px">
#                 <img style="max-width: none;" height="243" width="397" src="data:image/png;base64,..." />
#             </div>
#
#         </div>
#
#     </div>
# </div></div>
#         </div>
#
#     </div>
# </body>
# </html>
